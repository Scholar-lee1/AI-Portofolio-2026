# %% [markdown]
# <a href="https://colab.research.google.com/github/Scholar-lee1/AI-Portofolio-2026/blob/main/Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Create a tuple
student = ("Aminah Yusuf", 20, "Female", "Computer Science", "200 Level")

# Step 2: Display full tuple
print("Full student Bio Data: ")
print(student)

# Step 3: Access specific data
print("\nName and Department:")
print(student[0], "-", student[3])

# Step 4: Use negative indexing
print("\nLast two details (Department & Level):")
print(student[-2:])

# Step 5: Loop through tuple
labels = ["Name", "Age", "Gender", "Department", "Level"]
print("\nFormatted Student Info:")
for i in range(len(student)):
    print(f"{labels[i]}: {student[i]}")
# Out:
# Full student Bio Data:
# ('Aminah Yusuf', 20, 'Female', 'Computer Science', '200 Level')
#
# Name and Department:
# Aminah Yusuf - Computer Science
#
# Last two details (Department & Level):
# ('Computer Science', '200 Level')
#
# Formatted Student Info:
# Name: Aminah Yusuf
# Age: 20
# Gender: Female
# Department: Computer Science
# Level: 200 Level

# %%
def calculate_average(scores):
    return sum(scores) / len(scores)

def get_highest_and_lowest(scores):
    return max(scores), min(scores)

def analyze_performance(avg):
    if avg >= 70:
        return "Good performance"
    elif avg >= 50:
        return "Average performance"
    else:
        return "Poor prformance"

# Sample score
scores = [65, 70, 85, 50, 90, 45]

# Using the functions
average = calculate_average(scores)
highest, lowest = get_highest_and_lowest(scores)
performance = analyze_performance(average)

# Display results
print(f"Scores: {scores}")
print(f"Average Score: {average}")
print(f"Highest Score: {highest}")
print(f"lowest Score: {lowest}")
print(f"Performance Analysis: {performance}")
# Out:
# Scores: [65, 70, 85, 50, 90, 45]
# Average Score: 67.5
# Highest Score: 90
# lowest Score: 45
# Performance Analysis: Average performance
